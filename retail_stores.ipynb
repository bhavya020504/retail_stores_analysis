# %%
import pandas as pd #create
import numpy as np

data = {
    "Order_ID": [1001, 1002, 1003, 1004, 1005],
    "Date": ["2024-01-01", "2024-01-02", None, "2024-01-04", "2024-01-05"],  # Null date
    "Product": ["Shoes", "Laptop", "Mobile", None, "Watch"],  # Null product
    "Category": ["Fashion", "Electronics", "Electronics", "Fashion", None],  # Null category
    "Quantity": [2, None, 1, 3, 2],  # Null quantity
    "Price": [1200, 52000, None, 800, 3000],  # Null price
    "Customer": ["Kiran", "Priya", None, "Asha", "Rahul"],  # Null customer
    "City": ["Chennai", "Mumbai", "Delhi", "Bangalore", None]  # Null city
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       NaN  52000.0    Priya
# 2      1003        None  Mobile  Electronics       1.0      NaN     None
# 3      1004  2024-01-04    None      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch         None       2.0   3000.0    Rahul
#
#         City
# 0    Chennai
# 1     Mumbai
# 2      Delhi
# 3  Bangalore
# 4       None

# %%
df.head(2)#view the data
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       NaN  52000.0    Priya
#
#       City
# 0  Chennai
# 1   Mumbai

# %%
df.tail(2)
# Out:
#    Order_ID        Date Product Category  Quantity   Price Customer       City
# 3      1004  2024-01-04    None  Fashion       3.0   800.0     Asha  Bangalore
# 4      1005  2024-01-05   Watch     None       2.0  3000.0    Rahul       None

# %%
df.columns
# Out:
# Index(['Order_ID', 'Date', 'Product', 'Category', 'Quantity', 'Price',
#        'Customer', 'City'],
#       dtype='object')

# %%
df.shape
# Out:
# (5, 8)

# %%
df.info#readthedata
# Out:
# <bound method DataFrame.info of    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       NaN  52000.0    Priya
# 2      1003        None  Mobile  Electronics       1.0      NaN     None
# 3      1004  2024-01-04    None      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch         None       2.0   3000.0    Rahul
#
#         City
# 0    Chennai
# 1     Mumbai
# 2      Delhi
# 3  Bangalore
# 4       None  >

# %%
df.describe(include="all")
# Out:
#            Order_ID        Date Product Category  Quantity         Price  \
# count      5.000000           4       4        4  4.000000      4.000000
# unique          NaN           4       4        2       NaN           NaN
# top             NaN  2024-01-01   Shoes  Fashion       NaN           NaN
# freq            NaN           1       1        2       NaN           NaN
# mean    1003.000000         NaN     NaN      NaN  2.000000  14250.000000
# std        1.581139         NaN     NaN      NaN  0.816497  25184.849943
# min     1001.000000         NaN     NaN      NaN  1.000000    800.000000
# 25%     1002.000000         NaN     NaN      NaN  1.750000   1100.000000
# 50%     1003.000000         NaN     NaN      NaN  2.000000   2100.000000
# 75%     1004.000000         NaN     NaN      NaN  2.250000  15250.000000
# max     1005.000000         NaN     NaN      NaN  3.000000  52000.000000
#
#        Customer     City
# count         4        4
# unique        4        4
# ...

# %%
df.isnull()#nullvalues
# Out:
#    Order_ID   Date  Product  Category  Quantity  Price  Customer   City
# 0     False  False    False     False     False  False     False  False
# 1     False  False    False     False      True  False     False  False
# 2     False   True    False     False     False   True      True  False
# 3     False  False     True     False     False  False     False  False
# 4     False  False    False      True     False  False     False   True

# %%
df.isnull().sum()#incolums
# Out:
# Order_ID    0
# Date        1
# Product     1
# Category    1
# Quantity    1
# Price       1
# Customer    1
# City        1
# dtype: int64

# %%
df.isnull().sum().sum() #nullvaluesinentiretable
# Out:
# np.int64(7)

# %%
df.isnull().any(axis=1)
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# dtype: bool

# %%
df.isnull().any(axis=0)
# Out:
# Order_ID    False
# Date         True
# Product      True
# Category     True
# Quantity     True
# Price        True
# Customer     True
# City         True
# dtype: bool

# %%
df["Category"]#column names
# Out:
# 0        Fashion
# 1    Electronics
# 2    Electronics
# 3        Fashion
# 4           None
# Name: Category, dtype: object

# %%
df[["Date","Category"]]#multiplecolumns
# Out:
#          Date     Category
# 0  2024-01-01      Fashion
# 1  2024-01-02  Electronics
# 2        None  Electronics
# 3  2024-01-04      Fashion
# 4  2024-01-05         None

# %%
df.loc[3,"Quantity"]#selectingrows
# Out:
# np.float64(3.0)

# %%
df.loc[0:3]
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       NaN  52000.0    Priya
# 2      1003        None  Mobile  Electronics       1.0      NaN     None
# 3      1004  2024-01-04    None      Fashion       3.0    800.0     Asha
#
#         City
# 0    Chennai
# 1     Mumbai
# 2      Delhi
# 3  Bangalore

# %%
df.iloc[2:4,4]#selectcolumnsbyinteger
# Out:
# 2    1.0
# 3    3.0
# Name: Quantity, dtype: float64

# %%
#filtering rows

# %%
df[df["Price"]>3000]
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 1      1002  2024-01-02  Laptop  Electronics       NaN  52000.0    Priya
#
#      City
# 1  Mumbai

# %%
df[df["Price"]<2000]
# Out:
#    Order_ID        Date Product Category  Quantity   Price Customer       City
# 0      1001  2024-01-01   Shoes  Fashion       2.0  1200.0    Kiran    Chennai
# 3      1004  2024-01-04    None  Fashion       3.0   800.0     Asha  Bangalore

# %%
df[df["Product"]=="Shoes"]
# Out:
#    Order_ID        Date Product Category  Quantity   Price Customer     City
# 0      1001  2024-01-01   Shoes  Fashion       2.0  1200.0    Kiran  Chennai

# %%
df[df["Product"].isnull()]
# Out:
#    Order_ID        Date Product Category  Quantity  Price Customer       City
# 3      1004  2024-01-04    None  Fashion       3.0  800.0     Asha  Bangalore

# %%
#addingnewcolumns
df["Total"]=df["Quantity"]*df["Price"]

# %%
df["Total"]
# Out:
# 0    2400.0
# 1       0.0
# 2       NaN
# 3    2400.0
# 4    6000.0
# Name: Total, dtype: float64

# %%
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       NaN  52000.0    Priya
# 2      1003        None  Mobile  Electronics       1.0      NaN     None
# 3      1004  2024-01-04    None      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch         None       2.0   3000.0    Rahul
#
#         City   Total
# 0    Chennai  2400.0
# 1     Mumbai     NaN
# 2      Delhi     NaN
# 3  Bangalore  2400.0
# 4       None  6000.0

# %%
df.drop("Total",axis=1,inplace=True)

# %%
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       NaN  52000.0    Priya
# 2      1003        None  Mobile  Electronics       1.0      NaN     None
# 3      1004  2024-01-04    None      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch         None       2.0   3000.0    Rahul
#
#         City
# 0    Chennai
# 1     Mumbai
# 2      Delhi
# 3  Bangalore
# 4       None

# %%
df["Price"] = df["Price"].fillna(df["Price"].mean())#fillingthe missingvalue

# %%
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       NaN  52000.0    Priya
# 2      1003        None  Mobile  Electronics       1.0  14250.0     None
# 3      1004  2024-01-04    None      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch         None       2.0   3000.0    Rahul
#
#         City
# 0    Chennai
# 1     Mumbai
# 2      Delhi
# 3  Bangalore
# 4       None

# %%
df.fillna("Unknown")
# Out:
#    Order_ID        Date  Product     Category Quantity    Price Customer  \
# 0      1001  2024-01-01    Shoes      Fashion      2.0   1200.0    Kiran
# 1      1002  2024-01-02   Laptop  Electronics  Unknown  52000.0    Priya
# 2      1003     Unknown   Mobile  Electronics      1.0  14250.0  Unknown
# 3      1004  2024-01-04  Unknown      Fashion      3.0    800.0     Asha
# 4      1005  2024-01-05    Watch      Unknown      2.0   3000.0    Rahul
#
#         City
# 0    Chennai
# 1     Mumbai
# 2      Delhi
# 3  Bangalore
# 4    Unknown

# %%
#sorting
df.sort_values("Quantity",ascending=False)
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 3      1004  2024-01-04    None      Fashion       3.0    800.0     Asha
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 4      1005  2024-01-05   Watch         None       2.0   3000.0    Rahul
# 2      1003        None  Mobile  Electronics       1.0  14250.0     None
# 1      1002  2024-01-02  Laptop  Electronics       NaN  52000.0    Priya
#
#         City
# 3  Bangalore
# 0    Chennai
# 4       None
# 2      Delhi
# 1     Mumbai

# %%
df.sort_values("Price")
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 3      1004  2024-01-04    None      Fashion       3.0    800.0     Asha
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 4      1005  2024-01-05   Watch         None       2.0   3000.0    Rahul
# 2      1003        None  Mobile  Electronics       1.0  14250.0     None
# 1      1002  2024-01-02  Laptop  Electronics       NaN  52000.0    Priya
#
#         City
# 3  Bangalore
# 0    Chennai
# 4       None
# 2      Delhi
# 1     Mumbai

# %%
df.dropna(thresh=3, inplace=True)

# %%
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       NaN  52000.0    Priya
# 2      1003        None  Mobile  Electronics       1.0  14250.0     None
# 3      1004  2024-01-04    None      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch         None       2.0   3000.0    Rahul
#
#         City
# 0    Chennai
# 1     Mumbai
# 2      Delhi
# 3  Bangalore
# 4       None

# %%
df["Product"].replace("Shoes","shoes",inplace=True)
# Out:
# /tmp/ipython-input-2257540228.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Product"].replace("Shoes","shoes",inplace=True)

# %%
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       NaN  52000.0    Priya
# 2      1003        None  Mobile  Electronics       1.0  14250.0     None
# 3      1004  2024-01-04    None      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch         None       2.0   3000.0    Rahul
#
#         City
# 0    Chennai
# 1     Mumbai
# 2      Delhi
# 3  Bangalore
# 4       None

# %%
df["Product"].replace("shoes","Shoes",inplace=True)
# Out:
# /tmp/ipython-input-3835916881.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Product"].replace("shoes","Shoes",inplace=True)

# %%
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       NaN  52000.0    Priya
# 2      1003        None  Mobile  Electronics       1.0  14250.0     None
# 3      1004  2024-01-04    None      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch         None       2.0   3000.0    Rahul
#
#         City
# 0    Chennai
# 1     Mumbai
# 2      Delhi
# 3  Bangalore
# 4       None

# %%
df["Quantity"].fillna(0, inplace=True)
# Out:
# /tmp/ipython-input-3823344810.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Quantity"].fillna(0, inplace=True)

# %%
df["Category"].fillna("Electronics",inplace =True)
# Out:
# /tmp/ipython-input-1502265548.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Category"].fillna("Electronics",inplace =True)

# %%
df["Customer"].fillna("Rohith", inplace=True)
# Out:
# /tmp/ipython-input-2329978707.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Customer"].fillna("Rohith", inplace=True)

# %%
df["City"].fillna("Hyderabad", inplace=True)
# Out:
# /tmp/ipython-input-3928321459.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["City"].fillna("Hyderabad", inplace=True)

# %%
df["Product"].fillna("Suit", inplace=True)
# Out:
# /tmp/ipython-input-3454673646.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Product"].fillna("Suit", inplace=True)

# %%
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       0.0  52000.0    Priya
# 2      1003  2024-01-08  Mobile  Electronics       1.0  14250.0   Rohith
# 3      1004  2024-01-04    Suit      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch  Electronics       2.0   3000.0    Rahul
#
#         City
# 0    Chennai
# 1     Mumbai
# 2      Delhi
# 3  Bangalore
# 4  Hyderabad

# %%
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       0.0  52000.0    Priya
# 2      1003  2024-01-08  Mobile  Electronics       1.0      NaN   Rohith
# 3      1004  2024-01-04    Suit      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch  Electronics       2.0   3000.0    Rahul
#
#         City
# 0    Chennai
# 1     Mumbai
# 2      Delhi
# 3  Bangalore
# 4  Hyderabad

# %%
df["Region"]=["South","South","North","East","West"]

# %%
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       0.0  52000.0    Priya
# 2      1003  2024-01-08  Mobile  Electronics       1.0      NaN   Rohith
# 3      1004  2024-01-04    Suit      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch  Electronics       2.0   3000.0    Rahul
#
#         City Region
# 0    Chennai  South
# 1     Mumbai  South
# 2      Delhi  North
# 3  Bangalore   East
# 4  Hyderabad   West

# %%
df.set_index(["Region", "Order_ID"]) #MultiINdex
# Out:
#                        Date Product     Category  Quantity    Price Customer  \
# Region Order_ID
# South  1001      2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
#        1002      2024-01-02  Laptop  Electronics       0.0  52000.0    Priya
# North  1003      2024-01-08  Mobile  Electronics       1.0  14250.0   Rohith
# East   1004      2024-01-04    Suit      Fashion       3.0    800.0     Asha
# West   1005      2024-01-05   Watch  Electronics       2.0   3000.0    Rahul
#
#                       City
# Region Order_ID
# South  1001        Chennai
#        1002         Mumbai
# North  1003          Delhi
# East   1004      Bangalore
# West   1005      Hyderabad

# %%
df.groupby("Region")["Quantity"].sum()
# Out:
# Region
# East     3.0
# North    1.0
# South    2.0
# West     2.0
# Name: Quantity, dtype: float64

# %%
df.groupby("City")["Price"].sum()#to give the total prices in cities
# Out:
# City
# Bangalore      800.0
# Chennai       1200.0
# Delhi        14250.0
# Hyderabad     3000.0
# Mumbai       52000.0
# Name: Price, dtype: float64

# %%
df.groupby("Category")["Price"].mean()#average
# Out:
# Category
# Electronics    23083.333333
# Fashion         1000.000000
# Name: Price, dtype: float64

# %%
df.groupby("Region").agg({"Quantity":"sum","Price":"mean","Order_ID":"count"})
# Out:
#         Quantity    Price  Order_ID
# Region
# East         3.0    800.0         1
# North        1.0  14250.0         1
# South        2.0  26600.0         2
# West         2.0   3000.0         1

# %%
df.groupby(["Category", "Region"]).agg({
    "Quantity": "sum",
    "Price": "mean"
})
# Out:
#                     Quantity    Price
# Category    Region
# Electronics North        1.0  14250.0
#             South        0.0  52000.0
#             West         2.0   3000.0
# Fashion     East         3.0    800.0
#             South        2.0   1200.0

# %%
df.groupby("Region")["Quantity"].sum().sort_values(ascending=False)
# Out:
# Region
# East     3.0
# South    2.0
# West     2.0
# North    1.0
# Name: Quantity, dtype: float64

# %%
df.groupby("Region")["Price"].sum().idxmax()
# Out:
# 'South'

# %%
pivot1 = df.pivot_table(
    values='Quantity',
    index='Region',
    columns='Category',
    aggfunc='sum'
)

print(pivot1)
# Out:
# Category  Electronics  Fashion
# Region
# East              NaN      3.0
# North             1.0      NaN
# South             0.0      2.0
# West              2.0      NaN

# %%
pivot2 = df.pivot_table(
    values=['Quantity', 'Price'],
    index='Category',
    aggfunc={'Quantity': 'sum', 'Price': 'mean'},
    columns="Region"
)

print(pivot2)
# Out:
#              Price                           Quantity
# Region        East    North    South    West     East North South West
# Category
# Electronics    NaN  14250.0  52000.0  3000.0      NaN   1.0   0.0  2.0
# Fashion      800.0      NaN   1200.0     NaN      3.0   NaN   2.0  NaN

# %%
pivot_3=df.pivot_table(values=["Quantity","Price"],index="Region",columns="Product",aggfunc={"Quantity":"sum","Price":"mean"})
print(pivot_3)
# Out:
#            Price                                 Quantity                    \
# Product   Laptop   Mobile   Shoes   Suit   Watch   Laptop Mobile Shoes Suit
# Region
# East         NaN      NaN     NaN  800.0     NaN      NaN    NaN   NaN  3.0
# North        NaN  14250.0     NaN    NaN     NaN      NaN    1.0   NaN  NaN
# South    52000.0      NaN  1200.0    NaN     NaN      0.0    NaN   2.0  NaN
# West         NaN      NaN     NaN    NaN  3000.0      NaN    NaN   NaN  NaN
#
#
# Product Watch
# Region
# East      NaN
# North     NaN
# South     NaN
# West      2.0

# %%
pivot4 = df.pivot_table(
    values='Price',
    index=['Region', 'City'],
    columns='Category',
    aggfunc='sum'
)

print(pivot4)
# Out:
# Category          Electronics  Fashion
# Region City
# East   Bangalore          NaN    800.0
# North  Delhi          14250.0      NaN
# South  Chennai            NaN   1200.0
#        Mumbai         52000.0      NaN
# West   Hyderabad       3000.0      NaN

# %%
pivot5 = df.pivot_table(
    values='Quantity',
    index='Region',
    columns='Category',
    aggfunc='sum',
    fill_value=0,
    margins=True,       # Adds Row & Column Totals
    margins_name='Total'
)

print(pivot5)
# Out:
# Category  Electronics  Fashion  Total
# Region
# East              0.0      3.0    3.0
# North             1.0      0.0    1.0
# South             0.0      2.0    2.0
# West              2.0      0.0    2.0
# Total             3.0      5.0    8.0

# %%
data2 = {
    'Customer': ['Kiran', 'Priya', 'Rohith', 'Asha', 'Rahul', 'John'],
    'Age': [28, 32, 25, 30, 27, 40],
    'Gender': ['M', 'F', 'M', 'F', 'M', 'M']
}

df_customers = pd.DataFrame(data2)

# %%
df_customers
# Out:
#   Customer  Age Gender
# 0    Kiran   28      M
# 1    Priya   32      F
# 2   Rohith   25      M
# 3     Asha   30      F
# 4    Rahul   27      M
# 5     John   40      M

# %%
inner = df_customers.merge(df, on='Customer', how='inner')
print(inner)
# Out:
#   Customer  Age Gender  Order_ID        Date Product     Category  Quantity  \
# 0    Kiran   28      M      1001  2024-01-01   Shoes      Fashion       2.0
# 1    Priya   32      F      1002  2024-01-02  Laptop  Electronics       0.0
# 2   Rohith   25      M      1003  2024-01-08  Mobile  Electronics       1.0
# 3     Asha   30      F      1004  2024-01-04    Suit      Fashion       3.0
# 4    Rahul   27      M      1005  2024-01-05   Watch  Electronics       2.0
#
#      Price       City Region
# 0   1200.0    Chennai  South
# 1  52000.0     Mumbai  South
# 2  14250.0      Delhi  North
# 3    800.0  Bangalore   East
# 4   3000.0  Hyderabad   West

# %%
inner = df.merge(df_customers, on='Customer', how='inner')
print(inner)
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       0.0  52000.0    Priya
# 2      1003  2024-01-08  Mobile  Electronics       1.0  14250.0   Rohith
# 3      1004  2024-01-04    Suit      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch  Electronics       2.0   3000.0    Rahul
#
#         City Region  Age Gender
# 0    Chennai  South   28      M
# 1     Mumbai  South   32      F
# 2      Delhi  North   25      M
# 3  Bangalore   East   30      F
# 4  Hyderabad   West   27      M

# %%
outer=df.merge(df_customers, on='Customer', how='outer')
print(outer)
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0    1004.0  2024-01-04    Suit      Fashion       3.0    800.0     Asha
# 1       NaN         NaN     NaN          NaN       NaN      NaN     John
# 2    1001.0  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 3    1002.0  2024-01-02  Laptop  Electronics       0.0  52000.0    Priya
# 4    1005.0  2024-01-05   Watch  Electronics       2.0   3000.0    Rahul
# 5    1003.0  2024-01-08  Mobile  Electronics       1.0  14250.0   Rohith
#
#         City Region  Age Gender
# 0  Bangalore   East   30      F
# 1        NaN    NaN   40      M
# 2    Chennai  South   28      M
# 3     Mumbai  South   32      F
# 4  Hyderabad   West   27      M
# 5      Delhi  North   25      M

# %%
Left=df.merge(df_customers, on='Customer', how='left')
print(Left)
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       0.0  52000.0    Priya
# 2      1003  2024-01-08  Mobile  Electronics       1.0  14250.0   Rohith
# 3      1004  2024-01-04    Suit      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch  Electronics       2.0   3000.0    Rahul
#
#         City Region  Age Gender
# 0    Chennai  South   28      M
# 1     Mumbai  South   32      F
# 2      Delhi  North   25      M
# 3  Bangalore   East   30      F
# 4  Hyderabad   West   27      M

# %%
Right=df.merge(df_customers, on='Customer', how='right')
print(Right)
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0    1001.0  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1    1002.0  2024-01-02  Laptop  Electronics       0.0  52000.0    Priya
# 2    1003.0  2024-01-08  Mobile  Electronics       1.0  14250.0   Rohith
# 3    1004.0  2024-01-04    Suit      Fashion       3.0    800.0     Asha
# 4    1005.0  2024-01-05   Watch  Electronics       2.0   3000.0    Rahul
# 5       NaN         NaN     NaN          NaN       NaN      NaN     John
#
#         City Region  Age Gender
# 0    Chennai  South   28      M
# 1     Mumbai  South   32      F
# 2      Delhi  North   25      M
# 3  Bangalore   East   30      F
# 4  Hyderabad   West   27      M
# 5        NaN    NaN   40      M

# %%
df["Price_Rank"] = df["Price"].rank(ascending=False)

# %%
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       0.0  52000.0    Priya
# 2      1003  2024-01-08  Mobile  Electronics       1.0  14250.0   Rohith
# 3      1004  2024-01-04    Suit      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch  Electronics       2.0   3000.0    Rahul
#
#         City Region  Price_Rank
# 0    Chennai  South         4.0
# 1     Mumbai  South         1.0
# 2      Delhi  North         2.0
# 3  Bangalore   East         5.0
# 4  Hyderabad   West         3.0

# %%
df["Running_Quantity"] = df["Quantity"].cumsum()

# %%
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       0.0  52000.0    Priya
# 2      1003  2024-01-08  Mobile  Electronics       1.0  14250.0   Rohith
# 3      1004  2024-01-04    Suit      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch  Electronics       2.0   3000.0    Rahul
#
#         City Region  Price_Rank  Running_Quantity
# 0    Chennai  South         4.0               2.0
# 1     Mumbai  South         1.0               2.0
# 2      Delhi  North         2.0               3.0
# 3  Bangalore   East         5.0               6.0
# 4  Hyderabad   West         3.0               8.0

# %%
df["Price_MA_3"] = df["Price"].rolling(window=3).mean()

# %%
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       0.0  52000.0    Priya
# 2      1003  2024-01-08  Mobile  Electronics       1.0  14250.0   Rohith
# 3      1004  2024-01-04    Suit      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch  Electronics       2.0   3000.0    Rahul
#
#         City Region  Price_Rank  Running_Quantity    Price_MA_3
# 0    Chennai  South         4.0               2.0           NaN
# 1     Mumbai  South         1.0               2.0           NaN
# 2      Delhi  North         2.0               3.0  22483.333333
# 3  Bangalore   East         5.0               6.0  22350.000000
# 4  Hyderabad   West         3.0               8.0   6016.666667

# %%
df["3_Day_Quantity"] = df["Quantity"].rolling(2).sum()

# %%
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       0.0  52000.0    Priya
# 2      1003  2024-01-08  Mobile  Electronics       1.0  14250.0   Rohith
# 3      1004  2024-01-04    Suit      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch  Electronics       2.0   3000.0    Rahul
#
#         City Region  Price_Rank  Running_Quantity    Price_MA_3  \
# 0    Chennai  South         4.0               2.0           NaN
# 1     Mumbai  South         1.0               2.0           NaN
# 2      Delhi  North         2.0               3.0  22483.333333
# 3  Bangalore   East         5.0               6.0  22350.000000
# 4  Hyderabad   West         3.0               8.0   6016.666667
#
#    3_Day_Quantity
# 0             NaN
# 1             2.0
# 2             1.0
# 3             4.0
# 4             5.0

# %%
df["Region_Running_Qty"] = df.groupby("Region")["Quantity"].cumsum()
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       0.0  52000.0    Priya
# 2      1003  2024-01-08  Mobile  Electronics       1.0  14250.0   Rohith
# 3      1004  2024-01-04    Suit      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch  Electronics       2.0   3000.0    Rahul
#
#         City Region  Price_Rank  Running_Quantity    Price_MA_3  \
# 0    Chennai  South         4.0               2.0           NaN
# 1     Mumbai  South         1.0               2.0           NaN
# 2      Delhi  North         2.0               3.0  22483.333333
# 3  Bangalore   East         5.0               6.0  22350.000000
# 4  Hyderabad   West         3.0               8.0   6016.666667
#
#    3_Day_Quantity  Region_Running_Qty
# 0             NaN                 2.0
# 1             2.0                 2.0
# ...

# %%
df["Quantity_Change%"] = df["Quantity"].pct_change() * 100
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       0.0  52000.0    Priya
# 2      1003  2024-01-08  Mobile  Electronics       1.0  14250.0   Rohith
# 3      1004  2024-01-04    Suit      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch  Electronics       2.0   3000.0    Rahul
#
#         City Region  Price_Rank  Running_Quantity    Price_MA_3  \
# 0    Chennai  South         4.0               2.0           NaN
# 1     Mumbai  South         1.0               2.0           NaN
# 2      Delhi  North         2.0               3.0  22483.333333
# 3  Bangalore   East         5.0               6.0  22350.000000
# 4  Hyderabad   West         3.0               8.0   6016.666667
#
#    3_Day_Quantity  Region_Running_Qty  Quantity_Change%
# 0             NaN                 2.0               NaN
# ...

# %%
df["Prev_Quantity"] = df["Quantity"].shift(1)
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       0.0  52000.0    Priya
# 2      1003  2024-01-08  Mobile  Electronics       1.0  14250.0   Rohith
# 3      1004  2024-01-04    Suit      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch  Electronics       2.0   3000.0    Rahul
#
#         City Region  Price_Rank  Running_Quantity    Price_MA_3  \
# 0    Chennai  South         4.0               2.0           NaN
# 1     Mumbai  South         1.0               2.0           NaN
# 2      Delhi  North         2.0               3.0  22483.333333
# 3  Bangalore   East         5.0               6.0  22350.000000
# 4  Hyderabad   West         3.0               8.0   6016.666667
#
#    3_Day_Quantity  Region_Running_Qty  Quantity_Change%  Prev_Quantity
# ...

# %%
df["Next_Quantity"] = df["Quantity"].shift(-1)
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       0.0  52000.0    Priya
# 2      1003  2024-01-08  Mobile  Electronics       1.0  14250.0   Rohith
# 3      1004  2024-01-04    Suit      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch  Electronics       2.0   3000.0    Rahul
#
#         City Region  Price_Rank  Running_Quantity    Price_MA_3  \
# 0    Chennai  South         4.0               2.0           NaN
# 1     Mumbai  South         1.0               2.0           NaN
# 2      Delhi  North         2.0               3.0  22483.333333
# 3  Bangalore   East         5.0               6.0  22350.000000
# 4  Hyderabad   West         3.0               8.0   6016.666667
#
#    3_Day_Quantity  Region_Running_Qty  Quantity_Change%  Prev_Quantity  \
# ...

# %%
df["Expanding_Avg_Price"] = df["Price"].expanding().mean()
df
# Out:
#    Order_ID        Date Product     Category  Quantity    Price Customer  \
# 0      1001  2024-01-01   Shoes      Fashion       2.0   1200.0    Kiran
# 1      1002  2024-01-02  Laptop  Electronics       0.0  52000.0    Priya
# 2      1003  2024-01-08  Mobile  Electronics       1.0  14250.0   Rohith
# 3      1004  2024-01-04    Suit      Fashion       3.0    800.0     Asha
# 4      1005  2024-01-05   Watch  Electronics       2.0   3000.0    Rahul
#
#         City Region  Price_Rank  Running_Quantity    Price_MA_3  \
# 0    Chennai  South         4.0               2.0           NaN
# 1     Mumbai  South         1.0               2.0           NaN
# 2      Delhi  North         2.0               3.0  22483.333333
# 3  Bangalore   East         5.0               6.0  22350.000000
# 4  Hyderabad   West         3.0               8.0   6016.666667
#
#    3_Day_Quantity  Region_Running_Qty  Quantity_Change%  Prev_Quantity  \
# ...

# %%
df_melt = df.melt(
    id_vars=["Order_ID", "Product"],
    value_vars=["Quantity", "Price"],
    var_name="Metric",
    value_name="Value"
)

# %%
df_melt
# Out:
#    Order_ID Product    Metric    Value
# 0      1001   Shoes  Quantity      2.0
# 1      1002  Laptop  Quantity      0.0
# 2      1003  Mobile  Quantity      1.0
# 3      1004    Suit  Quantity      3.0
# 4      1005   Watch  Quantity      2.0
# 5      1001   Shoes     Price   1200.0
# 6      1002  Laptop     Price  52000.0
# 7      1003  Mobile     Price  14250.0
# 8      1004    Suit     Price    800.0
# 9      1005   Watch     Price   3000.0

# %%
df_stack = df.set_index(["Order_ID","Product"])[["Quantity", "Price"]].stack()
df_stack
# Out:
# Order_ID  Product
# 1001      Shoes    Quantity        2.0
#                    Price        1200.0
# 1002      Laptop   Quantity        0.0
#                    Price       52000.0
# 1003      Mobile   Quantity        1.0
#                    Price       14250.0
# 1004      Suit     Quantity        3.0
#                    Price         800.0
# 1005      Watch    Quantity        2.0
#                    Price        3000.0
# dtype: float64

# %%
df["Category"] = df["Category"].astype("category")

# %%
df.dtypes
# Out:
# Order_ID       int64
# Date          object
# Product       object
# Category    category
# Quantity     float64
# Price        float64
# Customer      object
# City          object
# Region        object
# dtype: object

# %%
df[["Category", "Region"]] = df[
    ["Category", "Region"]
].astype("category")
df.dtypes
# Out:
# Order_ID       int64
# Date          object
# Product       object
# Category    category
# Quantity     float64
# Price        float64
# Customer      object
# City          object
# Region      category
# dtype: object

# %%
df["Region"] = df["Region"].cat.reorder_categories(
    ["North", "South", "East", "West"],
    ordered=True
)

# %%
print(df["Region"].cat.categories)
# Out:
# Index(['North', 'South', 'East', 'West'], dtype='object')

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.dtypes
# Out:
# Order_ID             int64
# Date        datetime64[ns]
# Product             object
# Category          category
# Quantity           float64
# Price              float64
# Customer            object
# City                object
# Region            category
# dtype: object

# %%
df.set_index("Date",inplace=True)

# %%
df
# Out:
#             Order_ID Product     Category  Quantity    Price Customer  \
# Date
# 2024-01-01      1001   Shoes      Fashion       2.0   1200.0    Kiran
# 2024-01-02      1002  Laptop  Electronics       NaN  52000.0    Priya
# NaT             1003  Mobile  Electronics       1.0      NaN     None
# 2024-01-04      1004    None      Fashion       3.0    800.0     Asha
# 2024-01-05      1005   Watch          NaN       2.0   3000.0    Rahul
#
#                  City Region
# Date
# 2024-01-01    Chennai  South
# 2024-01-02     Mumbai  South
# NaT             Delhi  North
# 2024-01-04  Bangalore   East
# 2024-01-05       None   West

# %%
df.sort_index()
# Out:
#             Order_ID Product     Category  Quantity    Price Customer  \
# Date
# 2024-01-01      1001   Shoes      Fashion       2.0   1200.0    Kiran
# 2024-01-02      1002  Laptop  Electronics       NaN  52000.0    Priya
# 2024-01-04      1004    None      Fashion       3.0    800.0     Asha
# 2024-01-05      1005   Watch          NaN       2.0   3000.0    Rahul
# NaT             1003  Mobile  Electronics       1.0      NaN     None
#
#                  City Region
# Date
# 2024-01-01    Chennai  South
# 2024-01-02     Mumbai  South
# 2024-01-04  Bangalore   East
# 2024-01-05       None   West
# NaT             Delhi  North

# %%
df["Sales"] = df["Quantity"] * df["Price"]

monthly_sales = df["Sales"].resample("M").sum()
print(monthly_sales)
# Out:
# Date
# 2024-01-31    10800.0
# Name: Sales, dtype: float64
# /tmp/ipython-input-577114523.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_sales = df["Sales"].resample("M").sum()

# %%
df["Rolling_2_Day"] = df["Sales"].rolling(window=2).mean()

# %%
df
# Out:
#             Order_ID Product     Category  Quantity    Price Customer  \
# Date
# 2024-01-01      1001   Shoes      Fashion       2.0   1200.0    Kiran
# 2024-01-02      1002  Laptop  Electronics       0.0  52000.0    Priya
# NaT             1003  Mobile  Electronics       1.0  14250.0   Rohith
# 2024-01-04      1004    Suit      Fashion       3.0    800.0     Asha
# 2024-01-05      1005   Watch  Electronics       2.0   3000.0    Rahul
#
#                  City Region   Sales  Rolling_2_Day
# Date
# 2024-01-01    Chennai  South  2400.0            NaN
# 2024-01-02     Mumbai  South     NaN            NaN
# NaT             Delhi  North     NaN            NaN
# 2024-01-04  Bangalore   East  2400.0            NaN
# 2024-01-05  Hyderabad   West  6000.0         4200.0

# %%
df["Prev_Day_Sales"] = df["Sales"].shift(1)

# %%
df
# Out:
#             Order_ID Product     Category  Quantity    Price Customer  \
# Date
# 2024-01-01      1001   Shoes      Fashion       2.0   1200.0    Kiran
# 2024-01-02      1002  Laptop  Electronics       0.0  52000.0    Priya
# NaT             1003  Mobile  Electronics       1.0  14250.0   Rohith
# 2024-01-04      1004    Suit      Fashion       3.0    800.0     Asha
# 2024-01-05      1005   Watch  Electronics       2.0   3000.0    Rahul
#
#                  City Region   Sales  Rolling_2_Day  Prev_Day_Sales
# Date
# 2024-01-01    Chennai  South  2400.0            NaN             NaN
# 2024-01-02     Mumbai  South     NaN            NaN          2400.0
# NaT             Delhi  North     NaN            NaN             NaN
# 2024-01-04  Bangalore   East  2400.0            NaN             NaN
# 2024-01-05  Hyderabad   West  6000.0         4200.0          2400.0

# %%
df.loc["2024-01-05"]
# Out:
# Order_ID                 1005
# Product                 Watch
# Category          Electronics
# Quantity                  2.0
# Price                  3000.0
# Customer                Rahul
# City                Hyderabad
# Region                   West
# Sales                  6000.0
# Rolling_2_Day          4200.0
# Prev_Day_Sales         2400.0
# Name: 2024-01-05 00:00:00, dtype: object

# %%
df["Month"] = df.index.month
df["Year"] = df.index.year

df.groupby("Month")["Sales"].sum()
# Out:
# Month
# 1.0    10800.0
# Name: Sales, dtype: float64

# %%
df
# Out:
#             Order_ID Product     Category  Quantity    Price Customer  \
# Date
# 2024-01-01      1001   Shoes      Fashion       2.0   1200.0    Kiran
# 2024-01-02      1002  Laptop  Electronics       0.0  52000.0    Priya
# NaT             1003  Mobile  Electronics       1.0  14250.0   Rohith
# 2024-01-04      1004    Suit      Fashion       3.0    800.0     Asha
# 2024-01-05      1005   Watch  Electronics       2.0   3000.0    Rahul
#
#                  City Region   Sales  Rolling_2_Day  Prev_Day_Sales  Month  \
# Date
# 2024-01-01    Chennai  South  2400.0            NaN             NaN    1.0
# 2024-01-02     Mumbai  South     NaN            NaN          2400.0    1.0
# NaT             Delhi  North     NaN            NaN             NaN    NaN
# 2024-01-04  Bangalore   East  2400.0            NaN             NaN    1.0
# 2024-01-05  Hyderabad   West  6000.0         4200.0          2400.0    1.0
#
#               Year
# Date
# 2024-01-01  2024.0
# 2024-01-02  2024.0
# ...

# %%
df["Price_with_GST"] = df["Price"].apply(lambda x: x * 1.18)
df
# Out:
#             Order_ID Product     Category  Quantity    Price Customer  \
# Date
# 2024-01-01      1001   Shoes      Fashion       2.0   1200.0    Kiran
# 2024-01-02      1002  Laptop  Electronics       0.0  52000.0    Priya
# NaT             1003  Mobile  Electronics       1.0  14250.0   Rohith
# 2024-01-04      1004    Suit      Fashion       3.0    800.0     Asha
# 2024-01-05      1005   Watch  Electronics       2.0   3000.0    Rahul
#
#                  City Region   Sales  Rolling_2_Day  Prev_Day_Sales  Month  \
# Date
# 2024-01-01    Chennai  South  2400.0            NaN             NaN    1.0
# 2024-01-02     Mumbai  South     NaN            NaN          2400.0    1.0
# NaT             Delhi  North     NaN            NaN             NaN    NaN
# 2024-01-04  Bangalore   East  2400.0            NaN             NaN    1.0
# 2024-01-05  Hyderabad   West  6000.0         4200.0          2400.0    1.0
#
#               Year  Price_with_GST
# Date
# 2024-01-01  2024.0          1416.0
# ...

# %%
df["Sales"] = df["Quantity"] * df["Price"]

df["Sale_Status"] = df.apply(
    lambda row: "High Sale" if row["Sales"] > 10000 else "Normal Sale",
    axis=1
)

# %%
df
# Out:
#             Order_ID Product     Category  Quantity    Price Customer  \
# Date
# 2024-01-01      1001   Shoes      Fashion       2.0   1200.0    Kiran
# 2024-01-02      1002  Laptop  Electronics       0.0  52000.0    Priya
# NaT             1003  Mobile  Electronics       1.0  14250.0   Rohith
# 2024-01-04      1004    Suit      Fashion       3.0    800.0     Asha
# 2024-01-05      1005   Watch  Electronics       2.0   3000.0    Rahul
#
#                  City Region    Sales  Rolling_2_Day  Prev_Day_Sales  Month  \
# Date
# 2024-01-01    Chennai  South   2400.0            NaN             NaN    1.0
# 2024-01-02     Mumbai  South      0.0            NaN          2400.0    1.0
# NaT             Delhi  North  14250.0            NaN             NaN    NaN
# 2024-01-04  Bangalore   East   2400.0            NaN             NaN    1.0
# 2024-01-05  Hyderabad   West   6000.0         4200.0          2400.0    1.0
#
#               Year  Price_with_GST  Sale_Status
# Date
# ...

# %%
df["Region_Code"] = df["Region"].map({
    "North": 1,
    "South": 2,
    "East": 3,
    "West": 4
})

# %%
df
# Out:
#             Order_ID Product     Category  Quantity    Price Customer  \
# Date
# 2024-01-01      1001   Shoes      Fashion       2.0   1200.0    Kiran
# 2024-01-02      1002  Laptop  Electronics       0.0  52000.0    Priya
# NaT             1003  Mobile  Electronics       1.0  14250.0   Rohith
# 2024-01-04      1004    Suit      Fashion       3.0    800.0     Asha
# 2024-01-05      1005   Watch  Electronics       2.0   3000.0    Rahul
#
#                  City Region    Sales  Rolling_2_Day  Prev_Day_Sales  Month  \
# Date
# 2024-01-01    Chennai  South   2400.0            NaN             NaN    1.0
# 2024-01-02     Mumbai  South      0.0            NaN          2400.0    1.0
# NaT             Delhi  North  14250.0            NaN             NaN    NaN
# 2024-01-04  Bangalore   East   2400.0            NaN             NaN    1.0
# 2024-01-05  Hyderabad   West   6000.0         4200.0          2400.0    1.0
#
#               Year  Price_with_GST  Sale_Status Region_Code
# Date
# ...

# %%
df["Customer_Type"] = np.where(df["Sales"] > 10000, "Premium", "Regular")

# %%
df
# Out:
#             Order_ID Product     Category  Quantity    Price Customer  \
# Date
# 2024-01-01      1001   Shoes      Fashion       2.0   1200.0    Kiran
# 2024-01-02      1002  Laptop  Electronics       0.0  52000.0    Priya
# NaT             1003  Mobile  Electronics       1.0  14250.0   Rohith
# 2024-01-04      1004    Suit      Fashion       3.0    800.0     Asha
# 2024-01-05      1005   Watch  Electronics       2.0   3000.0    Rahul
#
#                  City Region    Sales  Rolling_2_Day  Prev_Day_Sales  Month  \
# Date
# 2024-01-01    Chennai  South   2400.0            NaN             NaN    1.0
# 2024-01-02     Mumbai  South      0.0            NaN          2400.0    1.0
# NaT             Delhi  North  14250.0            NaN             NaN    NaN
# 2024-01-04  Bangalore   East   2400.0            NaN             NaN    1.0
# 2024-01-05  Hyderabad   West   6000.0         4200.0          2400.0    1.0
#
#               Year  Price_with_GST  Sale_Status Region_Code Customer_Type
# ...

# %%
Q1 = df["Price"].quantile(0.25)
Q3 = df["Price"].quantile(0.75)
IQR = Q3 - Q1

df["Is_Outlier"] = np.where(
    (df["Price"] < (Q1 - 1.5*IQR)) | (df["Price"] > (Q3 + 1.5*IQR)),
    True, False
)

# %%
df
# Out:
#             Order_ID Product     Category  Quantity    Price Customer  \
# Date
# 2024-01-01      1001   Shoes      Fashion       2.0   1200.0    Kiran
# 2024-01-02      1002  Laptop  Electronics       0.0  52000.0    Priya
# NaT             1003  Mobile  Electronics       1.0  14250.0   Rohith
# 2024-01-04      1004    Suit      Fashion       3.0    800.0     Asha
# 2024-01-05      1005   Watch  Electronics       2.0   3000.0    Rahul
#
#                  City Region    Sales  Rolling_2_Day  Prev_Day_Sales  Month  \
# Date
# 2024-01-01    Chennai  South   2400.0            NaN             NaN    1.0
# 2024-01-02     Mumbai  South      0.0            NaN          2400.0    1.0
# NaT             Delhi  North  14250.0            NaN             NaN    NaN
# 2024-01-04  Bangalore   East   2400.0            NaN             NaN    1.0
# 2024-01-05  Hyderabad   West   6000.0         4200.0          2400.0    1.0
#
# ...

# %%
df_sorted = df.sort_values(["Region", "Sales"])

# %%
df_sorted
# Out:
#             Order_ID Product     Category  Quantity    Price Customer  \
# Date
# NaT             1003  Mobile  Electronics       1.0  14250.0   Rohith
# 2024-01-02      1002  Laptop  Electronics       0.0  52000.0    Priya
# 2024-01-01      1001   Shoes      Fashion       2.0   1200.0    Kiran
# 2024-01-04      1004    Suit      Fashion       3.0    800.0     Asha
# 2024-01-05      1005   Watch  Electronics       2.0   3000.0    Rahul
#
#                  City Region    Sales  Rolling_2_Day  Prev_Day_Sales  Month  \
# Date
# NaT             Delhi  North  14250.0            NaN             NaN    NaN
# 2024-01-02     Mumbai  South      0.0            NaN          2400.0    1.0
# 2024-01-01    Chennai  South   2400.0            NaN             NaN    1.0
# 2024-01-04  Bangalore   East   2400.0            NaN             NaN    1.0
# 2024-01-05  Hyderabad   West   6000.0         4200.0          2400.0    1.0
#
# ...

# %%
df_sorted = df.sort_values(["Region", "Sales"], ascending=[True, False])

# %%
df_sorted
# Out:
#             Order_ID Product     Category  Quantity    Price Customer  \
# Date
# NaT             1003  Mobile  Electronics       1.0  14250.0   Rohith
# 2024-01-01      1001   Shoes      Fashion       2.0   1200.0    Kiran
# 2024-01-02      1002  Laptop  Electronics       0.0  52000.0    Priya
# 2024-01-04      1004    Suit      Fashion       3.0    800.0     Asha
# 2024-01-05      1005   Watch  Electronics       2.0   3000.0    Rahul
#
#                  City Region    Sales  Rolling_2_Day  Prev_Day_Sales  Month  \
# Date
# NaT             Delhi  North  14250.0            NaN             NaN    NaN
# 2024-01-01    Chennai  South   2400.0            NaN             NaN    1.0
# 2024-01-02     Mumbai  South      0.0            NaN          2400.0    1.0
# 2024-01-04  Bangalore   East   2400.0            NaN             NaN    1.0
# 2024-01-05  Hyderabad   West   6000.0         4200.0          2400.0    1.0
#
# ...

# %%
df_sorted = df.sort_values(["Date", "Sales"])
df_sorted
# Out:
#             Order_ID Product     Category  Quantity    Price Customer  \
# Date
# 2024-01-01      1001   Shoes      Fashion       2.0   1200.0    Kiran
# 2024-01-02      1002  Laptop  Electronics       0.0  52000.0    Priya
# 2024-01-04      1004    Suit      Fashion       3.0    800.0     Asha
# 2024-01-05      1005   Watch  Electronics       2.0   3000.0    Rahul
# NaT             1003  Mobile  Electronics       1.0  14250.0   Rohith
#
#                  City Region    Sales  Rolling_2_Day  Prev_Day_Sales  Month  \
# Date
# 2024-01-01    Chennai  South   2400.0            NaN             NaN    1.0
# 2024-01-02     Mumbai  South      0.0            NaN          2400.0    1.0
# 2024-01-04  Bangalore   East   2400.0            NaN             NaN    1.0
# 2024-01-05  Hyderabad   West   6000.0         4200.0          2400.0    1.0
# NaT             Delhi  North  14250.0            NaN             NaN    NaN
#
# ...

# %%
df["Category"] = df["Category"].astype("category")
df["Quantity"] = pd.to_numeric(df["Quantity"], downcast="integer")

# %%
df
# Out:
#             Order_ID Product     Category  Quantity    Price Customer  \
# Date
# 2024-01-01      1001   Shoes      Fashion         2   1200.0    Kiran
# 2024-01-02      1002  Laptop  Electronics         0  52000.0    Priya
# NaT             1003  Mobile  Electronics         1  14250.0   Rohith
# 2024-01-04      1004    Suit      Fashion         3    800.0     Asha
# 2024-01-05      1005   Watch  Electronics         2   3000.0    Rahul
#
#                  City Region    Sales  Rolling_2_Day  Prev_Day_Sales  Month  \
# Date
# 2024-01-01    Chennai  South   2400.0            NaN             NaN    1.0
# 2024-01-02     Mumbai  South      0.0            NaN          2400.0    1.0
# NaT             Delhi  North  14250.0            NaN             NaN    NaN
# 2024-01-04  Bangalore   East   2400.0            NaN             NaN    1.0
# 2024-01-05  Hyderabad   West   6000.0         4200.0          2400.0    1.0
#
# ...

# %%
df.dtypes
# Out:
# Order_ID             int64
# Product             object
# Category          category
# Quantity              int8
# Price              float64
# Customer            object
# City                object
# Region            category
# Sales              float64
# Rolling_2_Day      float64
# Prev_Day_Sales     float64
# Month              float64
# Year               float64
# Price_with_GST     float64
# Sale_Status         object
# Region_Code       category
# Customer_Type       object
# Is_Outlier            bool
# dtype: object

# %%
df.info(memory_usage="deep")
df.memory_usage(deep=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2024-01-01 to 2024-01-05
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        5 non-null      int64
#  1   Product         5 non-null      object
#  2   Category        5 non-null      category
#  3   Quantity        5 non-null      int8
#  4   Price           5 non-null      float64
#  5   Customer        5 non-null      object
#  6   City            5 non-null      object
#  7   Region          5 non-null      category
#  8   Sales           5 non-null      float64
#  9   Rolling_2_Day   1 non-null      float64
#  10  Prev_Day_Sales  2 non-null      float64
#  11  Month           4 non-null      float64
#  12  Year            4 non-null      float64
#  13  Price_with_GST  5 non-null      float64
#  14  Sale_Status     5 non-null      object
#  15  Region_Code     5 non-null      category
# ...
